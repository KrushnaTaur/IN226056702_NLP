# %% [markdown]
# <a href="https://colab.research.google.com/github/KrushnaTaur/IN226056702_NLP/blob/main/Task_1_NLP_Preprocessing_Engine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 1: Conceptual Answers

# %% [markdown]
# ## 1. Difference between "Love" and "love" in NLP
# In NLP, "Love" and "love" are treated as different tokens if case normalization is not applied.
# This increases vocabulary size unnecessarily.
# So we convert text to lowercase to treat them the same.

# %% [markdown]
# ## 2. What happens if stopwords are not removed?
# Dataset becomes noisy and large
# Common words like the, is, and dominate frequency
# Model may focus on irrelevant words
# Reduced performance and efficiency

# %% [markdown]
# ## 3. Two cases where removing stopwords is harmful
# Sentiment Analysis
# Example:
# "I am not happy" → removing not changes meaning
#
# Question Answering / Chatbots
# Example:
# "What is your name?" → removing what, is breaks intent

# %% [markdown]
# # Task 2: Advanced Preprocessing Function

# %%
import re

def preprocess_text(text):
    if not text or not isinstance(text, str):
        return [], ""

    # Remove URLs
    text = re.sub(r'http\S+|www\S+', '', text)

    # Remove emails
    text = re.sub(r'\S+@\S+', '', text)

    # Remove numbers
    text = re.sub(r'\d+', '', text)

    # Remove emojis (basic way)
    text = re.sub(r'[^\x00-\x7F]+', '', text)

    # Lowercase
    text = text.lower()

    # Handle repeated characters
    text = re.sub(r'(.)\1{2,}', r'\1', text)

    # Remove special characters
    text = re.sub(r'[^a-z\s]', '', text)

    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()

    tokens = text.split()

    # Remove short words
    tokens = [word for word in tokens if len(word) > 2 or word in ['no', 'not']]

    clean_sentence = " ".join(tokens)

    return tokens, clean_sentence

# %% [markdown]
# # Task 3: Stress Testing

# %%
test_sentences = [
    "Get 100% FREE access now!!!",
    "I absolutely looooved this product 😍😍",
    "Worst service ever... 0/10",
    "Call me at 9876543210",
    "This is THE best course!!!",
    "Visit https://openai.com now!",
    "Nooooo this is baaad!!!",
    "OK OK OK I got it",
    "Win $$$ now!!! Limited offer!!!",
    "I am not happy with this"
]

for text in test_sentences:
    tokens, clean = preprocess_text(text)

    print("Original:", text)
    print("Tokens:", tokens)
    print("Clean Sentence:", clean)
    print("-"*50)
# Out:
# Original: Get 100% FREE access now!!!
# Tokens: ['get', 'free', 'access', 'now']
# Clean Sentence: get free access now
# --------------------------------------------------
# Original: I absolutely looooved this product 😍😍
# Tokens: ['absolutely', 'loved', 'this', 'product']
# Clean Sentence: absolutely loved this product
# --------------------------------------------------
# Original: Worst service ever... 0/10
# Tokens: ['worst', 'service', 'ever']
# Clean Sentence: worst service ever
# --------------------------------------------------
# Original: Call me at 9876543210
# Tokens: ['call']
# Clean Sentence: call
# --------------------------------------------------
# Original: This is THE best course!!!
# Tokens: ['this', 'the', 'best', 'course']
# Clean Sentence: this the best course
# --------------------------------------------------
# Original: Visit https://openai.com now!
# Tokens: ['visit', 'now']
# Clean Sentence: visit now
# --------------------------------------------------
# ...

# %% [markdown]
# # Task 4: Token Analytics

# %%
def analyze_tokens(tokens):
    if len(tokens) == 0:
        return 0, 0, 0

    total = len(tokens)
    unique = len(set(tokens))
    avg_len = sum(len(t) for t in tokens) / total

    return total, unique, round(avg_len, 2)

for text in test_sentences:
    tokens, clean = preprocess_text(text)

    total, unique, avg = analyze_tokens(tokens)

    print(f"Sentence: {clean}")
    print(f"Total Tokens: {total}, Unique: {unique}, Avg Length: {avg}")
    print("-"*50)
# Out:
# Sentence: get free access now
# Total Tokens: 4, Unique: 4, Avg Length: 4.0
# --------------------------------------------------
# Sentence: absolutely loved this product
# Total Tokens: 4, Unique: 4, Avg Length: 6.5
# --------------------------------------------------
# Sentence: worst service ever
# Total Tokens: 3, Unique: 3, Avg Length: 5.33
# --------------------------------------------------
# Sentence: call
# Total Tokens: 1, Unique: 1, Avg Length: 4.0
# --------------------------------------------------
# Sentence: this the best course
# Total Tokens: 4, Unique: 4, Avg Length: 4.25
# --------------------------------------------------
# Sentence: visit now
# Total Tokens: 2, Unique: 2, Avg Length: 4.0
# --------------------------------------------------
# Sentence: no this bad
# Total Tokens: 3, Unique: 3, Avg Length: 3.0
# --------------------------------------------------
# Sentence: got
# Total Tokens: 1, Unique: 1, Avg Length: 3.0
# ...

# %% [markdown]
# # Task 5: Frequency Analysis

# %%
from collections import Counter

all_tokens = []

for text in test_sentences:
    tokens, _ = preprocess_text(text)
    all_tokens.extend(tokens)

counter = Counter(all_tokens)

print("Top 10 Frequent Words:")
print(counter.most_common(10))

print("\nTop 5 Least Frequent Words:")
print(counter.most_common()[-5:])
# Out:
# Top 10 Frequent Words:
# [('this', 4), ('now', 3), ('get', 1), ('free', 1), ('access', 1), ('absolutely', 1), ('loved', 1), ('product', 1), ('worst', 1), ('service', 1)]
#
# Top 5 Least Frequent Words:
# [('limited', 1), ('offer', 1), ('not', 1), ('happy', 1), ('with', 1)]

# %% [markdown]
# # Task 6: Full Pipeline

# %%
def full_pipeline(text_list):
    all_tokens = []
    clean_sentences = []

    for text in text_list:
        tokens, clean = preprocess_text(text)
        all_tokens.extend(tokens)
        clean_sentences.append(clean)

    return {
        "tokens": all_tokens,
        "clean_sentences": clean_sentences
    }

# Test
output = full_pipeline(test_sentences)
print(output)
# Out:
# {'tokens': ['get', 'free', 'access', 'now', 'absolutely', 'loved', 'this', 'product', 'worst', 'service', 'ever', 'call', 'this', 'the', 'best', 'course', 'visit', 'now', 'no', 'this', 'bad', 'got', 'win', 'now', 'limited', 'offer', 'not', 'happy', 'with', 'this'], 'clean_sentences': ['get free access now', 'absolutely loved this product', 'worst service ever', 'call', 'this the best course', 'visit now', 'no this bad', 'got', 'win now limited offer', 'not happy with this']}

# %% [markdown]
# # Task 7: Error Handling

# %%
edge_cases = ["", "😂😂😂", "123456"]

for text in edge_cases:
    print(preprocess_text(text))
# Out:
# ([], '')
# ([], '')
# ([], '')
